# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# /home/shan/Packages/anaconda3/envs/tax3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
df = pd.read_csv('out/taxi_distributional_semantics_results.csv')

# %%
df.head()
# Out:
#    buffer attached    parent    family  iterations    recall  precision  \
# 0       5      yes  poincare  fasttext           1  0.322581   0.420168
# 1       5      yes  poincare  fasttext           2  0.322581   0.423729
# 2       5      yes  poincare  fasttext           3  0.322581   0.426136
# 3       5      yes  poincare  fasttext           4  0.322581   0.426136
# 4       5      yes  poincare  fasttext           5  0.318280   0.425287
#
#          f1       f_m
# 0  0.364964  0.091352
# 1  0.366300  0.091352
# 2  0.367197  0.091352
# 3  0.367197  0.091352
# 4  0.364084  0.091352

# %%
df.loc[(df['buffer'] == 5) & (df['attached'] == 'yes')]
# Out:
#     buffer attached    parent    family  iterations    recall  precision  \
# 0        5      yes  poincare  fasttext           1  0.322581   0.420168
# 1        5      yes  poincare  fasttext           2  0.322581   0.423729
# 2        5      yes  poincare  fasttext           3  0.322581   0.426136
# 3        5      yes  poincare  fasttext           4  0.322581   0.426136
# 4        5      yes  poincare  fasttext           5  0.318280   0.425287
# 5        5      yes  poincare  fasttext           6  0.318280   0.427746
# 6        5      yes  poincare  fasttext           7  0.318280   0.427746
# 7        5      yes  poincare  fasttext           8  0.318280   0.427746
# 8        5      yes  poincare  fasttext           9  0.318280   0.427746
# 9        5      yes  poincare  fasttext          10  0.318280   0.427746
# 10       5      yes  poincare         -           1  0.322581   0.420168
# 11       5      yes  poincare         -           2  0.322581   0.422535
# ...
